# %%
import transcribe as ts


input_filepath = "24-y034497-01_US02_170624_12.30pm_Strictly Confidential.mp4"

ts.transcribe_audio(input_filepath)
# Out:
# Processing 13 transcript chunks. Estimated time: 390 seconds.
# Processed transcription segment. Elapsed: 21.24235486984253 seconds.
# Processed chunk at index 0
# Finish reason: stop
# Processed transcription segment. Elapsed: 50.74899935722351 seconds.
# Processed chunk at index 1
# Finish reason: stop
# Processed transcription segment. Elapsed: 28.204376697540283 seconds.
# Processed chunk at index 2
# Finish reason: stop
# Processed transcription segment. Elapsed: 10.032503843307495 seconds.
# Processed chunk at index 3
# Finish reason: stop
# Processed transcription segment. Elapsed: 36.81092882156372 seconds.
# Processed chunk at index 4
# Finish reason: stop
# Processed transcription segment. Elapsed: 21.56126308441162 seconds.
# Processed chunk at index 5
# Finish reason: stop
# Processed transcription segment. Elapsed: 21.70370101928711 seconds.
# Processed chunk at index 6
# Finish reason: stop
# Processed transcription segment. Elapsed: 15.45432996749878 seconds.
# ...
